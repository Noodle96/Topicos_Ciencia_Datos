# %% [markdown]
# ***Leer los primeros 256 bytes del header general***

# %% [markdown]
# <p align="center">
#     <img src="../../assets/img/headerGeneral.png" alt="Texto alternativo" width="450"/>
# </p>
#
# <!-- ![Ejemplo de imagen](../../assets/img/HeaderRecord.png) -->

# %% [markdown]
# <!-- Insertar una imag

# %%
def read_general_header(edf_path: str) -> bytes:
    with open(edf_path, 'rb') as f:
        header_bytes = f.read(256)
    return header_bytes

# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaauj/s004_2012/01_tcp_ar/aaaaaauj_s004_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaamtj/s002_2012/01_tcp_ar/aaaaamtj_s002_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaamtj/s001_2012/01_tcp_ar/aaaaamtj_s001_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaamtj/s001_2012/01_tcp_ar/aaaaamtj_s001_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaamtj/s001_2012/01_tcp_ar/aaaaamtj_s001_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaauj/s002_2003/02_tcp_le/aaaaaauj_s002_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaauj/s003_2003/02_tcp_le/aaaaaauj_s003_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaauj/s001_2003/02_tcp_le/aaaaaauj_s001_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaauj/s004_2012/01_tcp_ar/aaaaaauj_s004_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s002_2004/02_tcp_le/aaaaaedy_s002_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s003_2004/02_tcp_le/aaaaaedy_s003_t000.edf"

# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaamtj/s002_2012/01_tcp_ar/aaaaamtj_s002_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaamtj/s001_2012/01_tcp_ar/aaaaamtj_s001_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaamtj/s001_2012/01_tcp_ar/aaaaamtj_s001_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaamtj/s001_2012/01_tcp_ar/aaaaamtj_s001_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaauj/s002_2003/02_tcp_le/aaaaaauj_s002_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaauj/s003_2003/02_tcp_le/aaaaaauj_s003_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaauj/s001_2003/02_tcp_le/aaaaaauj_s001_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaauj/s004_2012/01_tcp_ar/aaaaaauj_s004_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s002_2004/02_tcp_le/aaaaaedy_s002_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s003_2004/02_tcp_le/aaaaaedy_s003_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s001_2004/01_tcp_ar/aaaaaedy_s001_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s001_2004/01_tcp_ar/aaaaaedy_s001_t005.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s001_2004/01_tcp_ar/aaaaaedy_s001_t006.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s001_2004/01_tcp_ar/aaaaaedy_s001_t004.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s001_2004/01_tcp_ar/aaaaaedy_s001_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s001_2004/01_tcp_ar/aaaaaedy_s001_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s001_2004/01_tcp_ar/aaaaaedy_s001_t007.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedy/s001_2004/01_tcp_ar/aaaaaedy_s001_t003.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaadax/s001_2004/02_tcp_le/aaaaadax_s001_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaaql/s001_2003/02_tcp_le/aaaaaaql_s001_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaegv/s001_2006/02_tcp_le/aaaaaegv_s001_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaacut/s001_2004/02_tcp_le/aaaaacut_s001_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t007.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t010.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t005.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t004.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t009.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t006.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t008.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s009_2015/01_tcp_ar/aaaaambs_s009_t003.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t003.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t005.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t007.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t004.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t009.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t006.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s012_2015/01_tcp_ar/aaaaambs_s012_t008.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t006.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t004.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t009.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t008.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t003.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t005.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s013_2015/01_tcp_ar/aaaaambs_s013_t007.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t007.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t010.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t004.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t006.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t008.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t003.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t005.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s011_2015/01_tcp_ar/aaaaambs_s011_t009.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t006.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t005.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t008.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t010.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t004.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t007.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t009.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s010_2015/01_tcp_ar/aaaaambs_s010_t003.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t008.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t004.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t009.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t007.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t005.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t010.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t003.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaambs/s014_2015/01_tcp_ar/aaaaambs_s014_t006.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaahxq/s004_2009/02_tcp_le/aaaaahxq_s004_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaahxq/s004_2009/02_tcp_le/aaaaahxq_s004_t003.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaahxq/s004_2009/02_tcp_le/aaaaahxq_s004_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaahxq/s004_2009/02_tcp_le/aaaaahxq_s004_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaaedz/s001_2004/02_tcp_le/aaaaaedz_s001_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaapgz/s001_2013/01_tcp_ar/aaaaapgz_s001_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaahcp/s002_2009/02_tcp_le/aaaaahcp_s002_t001.edf"
data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaapxw/s003_2013/01_tcp_ar/aaaaapxw_s003_t006.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaapxw/s003_2013/01_tcp_ar/aaaaapxw_s003_t004.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaapxw/s003_2013/01_tcp_ar/aaaaapxw_s003_t001.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaapxw/s003_2013/01_tcp_ar/aaaaapxw_s003_t005.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaapxw/s003_2013/01_tcp_ar/aaaaapxw_s003_t000.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaapxw/s003_2013/01_tcp_ar/aaaaapxw_s003_t002.edf"
# data_path = "../dataset/tuh_eeg_seizure/v2.0.3/edf/train/aaaaapxw/s003_2013/01_tcp_ar/aaaaapxw_s003_t008.edf"

header = read_general_header(data_path)
print("Header length:", len(header))
print(header.decode('ascii', errors='replace'))  # reemplaza errores de codificación
# Out:
# Header length: 256
# 0       aaaaapxw F 01-JAN-0000 aaaaapxw Age:67                                          Startdate 01-JAN-2019 aaaaapxw_s003 XXX #                                       01.01.1300.00.007424                                                601     1.00000028

# %% [markdown]
# - Ver la informacion que se guarda en el header

# %% [markdown]
# | Campo                          | Bytes   | Longitud | Comentario                                  |
# | ------------------------------ | ------- | -------- | ------------------------------------------- |
# | Version of data format         | 0–7     | 8        | Versión del formato EDF |
# | Local patient identification   | 8–87    | 80       | Información del paciente                      |
# | Local recording identification | 88–167  | 80       | Información sobre el estudio o grabacion                |
# | Start date of recording        | 168–175 | 8        | Fecha de inicio de la grabación en formato dd.mm.yy                         |
# | Start time of recording        | 176–183 | 8        | Hora de inicio en formato hh.mm.ss                         |
# | Number of bytes in header      | 184–191 | 8        | Número de bytes totales del header                          |
# | Reserved                       | 192–235 | 44       | Uso libre, algunos ponen etiquetas          |
# | Number of data records         | 236–243 | 8        | Número de bloques de datos ("registros")                        |
# | Duration of a data record (s)  | 244–251 | 8        |  Duración de cada registro de datos, en segundos        |
# | Number of signals (channels)   | 252–255 | 4        | Número total de señales o canales                            |

# %%
version = header[0:8].decode().strip()
local_patient_id = header[8:88].decode().strip()
local_recording_id = header[88:168].decode().strip()
start_date = header[168:176].decode().strip()
start_time = header[176:184].decode().strip()
header_length = header[184:192].decode().strip()
reserved = header[192:236].decode().strip()
number_of_data_records = header[236:244].decode().strip()
duration_of_data_record = header[244:252].decode().strip()
n_signals = int(header[252:256].decode().strip())

print(f"Versión EDF: {version}")
print(f"ID del paciente: {local_patient_id}")
print(f"ID de la grabación: {local_recording_id}")
print(f"Fecha inicio: {start_date}")
print(f"Hora inicio: {start_time}")
print(f"Longitud del encabezado: {header_length}")
print(f"Reservado: {reserved}")
print(f"Número de registros de datos: {number_of_data_records}")
print(f"Duración de cada registro de datos: {duration_of_data_record}")
print(f"Número de canales: {n_signals}")
# Out:
# Versión EDF: 0
# ID del paciente: aaaaapxw F 01-JAN-0000 aaaaapxw Age:67
# ID de la grabación: Startdate 01-JAN-2019 aaaaapxw_s003 XXX #
# Fecha inicio: 01.01.13
# Hora inicio: 00.00.00
# Longitud del encabezado: 7424
# Reservado:
# Número de registros de datos: 601
# Duración de cada registro de datos: 1.000000
# Número de canales: 28

# %%
256 + 256*30 # 7936
# Out:
# 7936

# %%
from typing import Any, Dict, List
import pyedflib
import os

def extract_patient_id_from_path(path: str) -> str:
    parts: str = os.path.normpath(path).split(os.sep)
    return parts[-4] if len(parts) >= 4 else "unknown"

def extract_edf_metadata(edf_paths: List[str]) -> List[Dict[str, Any]]:
    metadata: List[Dict[str, Any]] = []
    for path in edf_paths:
        try:
            f = pyedflib.EdfReader(path)

            # in read byte, similar to number_of_data_records = header[236:244].decode().strip()
            duration_sec = f.file_duration 

            # in read byte, similar to signals_in_file = header[252:255].decode().strip()
            n_channels = f.signals_in_file
            
            patient_id = extract_patient_id_from_path(path)
            filename = os.path.basename(path)

            metadata.append({
                "filename": filename,
                "filepath": path,
                "patient_id": patient_id,
                "duration_sec": duration_sec,
                "n_channels": n_channels
            })
            f._close()
            del f
        except Exception as e:
            print(f"❌ Error procesando {path}: {e}")
    return metadata

extract_edf_metadata()
