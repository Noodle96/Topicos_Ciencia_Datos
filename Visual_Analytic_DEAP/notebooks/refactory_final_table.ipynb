# %%
from __future__ import annotations

import pandas as pd


data: list[dict[str, object]] = [
    {"Participant": "s01", "Channels": 48, "Record": 1.0, "Records": 3869, "Duration": "64.48 min", "Samples": 512, "Total samples": 95084544, "BDF size": "0.266 GB", "RAM float32": "0.354 GB"},
    {"Participant": "s02", "Channels": 48, "Record": 1.0, "Records": 3703, "Duration": "61.72 min", "Samples": 512, "Total samples": 91004928, "BDF size": "0.254 GB", "RAM float32": "0.339 GB"},
    {"Participant": "s03", "Channels": 48, "Record": 1.0, "Records": 3885, "Duration": "64.75 min", "Samples": 512, "Total samples": 95477760, "BDF size": "0.267 GB", "RAM float32": "0.356 GB"},
    {"Participant": "s04", "Channels": 48, "Record": 1.0, "Records": 3301, "Duration": "55.02 min", "Samples": 512, "Total samples": 81125376, "BDF size": "0.227 GB", "RAM float32": "0.302 GB"},
    {"Participant": "s05", "Channels": 48, "Record": 1.0, "Records": 3916, "Duration": "65.27 min", "Samples": 512, "Total samples": 96239616, "BDF size": "0.269 GB", "RAM float32": "0.359 GB"},
    {"Participant": "s06", "Channels": 48, "Record": 1.0, "Records": 3586, "Duration": "59.77 min", "Samples": 512, "Total samples": 88129536, "BDF size": "0.246 GB", "RAM float32": "0.328 GB"},
    {"Participant": "s07", "Channels": 48, "Record": 1.0, "Records": 3571, "Duration": "59.52 min", "Samples": 512, "Total samples": 87760896, "BDF size": "0.245 GB", "RAM float32": "0.327 GB"},
    {"Participant": "s08", "Channels": 48, "Record": 1.0, "Records": 3517, "Duration": "58.62 min", "Samples": 512, "Total samples": 86433792, "BDF size": "0.242 GB", "RAM float32": "0.322 GB"},
    {"Participant": "s09", "Channels": 48, "Record": 1.0, "Records": 3767, "Duration": "62.78 min", "Samples": 512, "Total samples": 92577792, "BDF size": "0.259 GB", "RAM float32": "0.345 GB"},
    {"Participant": "s10", "Channels": 48, "Record": 1.0, "Records": 3512, "Duration": "58.53 min", "Samples": 512, "Total samples": 86310912, "BDF size": "0.241 GB", "RAM float32": "0.322 GB"},
    {"Participant": "s11", "Channels": 48, "Record": 1.0, "Records": 4161, "Duration": "69.35 min", "Samples": 512, "Total samples": 102260736, "BDF size": "0.286 GB", "RAM float32": "0.381 GB"},
    {"Participant": "s12", "Channels": 48, "Record": 1.0, "Records": 3498, "Duration": "58.30 min", "Samples": 512, "Total samples": 85966848, "BDF size": "0.240 GB", "RAM float32": "0.320 GB"},
    {"Participant": "s13", "Channels": 48, "Record": 1.0, "Records": 3711, "Duration": "61.85 min", "Samples": 512, "Total samples": 91201536, "BDF size": "0.255 GB", "RAM float32": "0.340 GB"},
    {"Participant": "s14", "Channels": 48, "Record": 1.0, "Records": 3937, "Duration": "65.62 min", "Samples": 512, "Total samples": 96755712, "BDF size": "0.270 GB", "RAM float32": "0.360 GB"},
    {"Participant": "s15", "Channels": 48, "Record": 1.0, "Records": 4072, "Duration": "67.87 min", "Samples": 512, "Total samples": 100073472, "BDF size": "0.280 GB", "RAM float32": "0.373 GB"},
    {"Participant": "s16", "Channels": 48, "Record": 1.0, "Records": 3683, "Duration": "61.38 min", "Samples": 512, "Total samples": 90513408, "BDF size": "0.253 GB", "RAM float32": "0.337 GB"},
    {"Participant": "s17", "Channels": 48, "Record": 1.0, "Records": 3446, "Duration": "57.43 min", "Samples": 512, "Total samples": 84688896, "BDF size": "0.237 GB", "RAM float32": "0.315 GB"},
    {"Participant": "s18", "Channels": 48, "Record": 1.0, "Records": 3628, "Duration": "60.47 min", "Samples": 512, "Total samples": 89161728, "BDF size": "0.249 GB", "RAM float32": "0.332 GB"},
    {"Participant": "s19", "Channels": 48, "Record": 1.0, "Records": 3746, "Duration": "62.43 min", "Samples": 512, "Total samples": 92061696, "BDF size": "0.257 GB", "RAM float32": "0.343 GB"},
    {"Participant": "s20", "Channels": 48, "Record": 1.0, "Records": 3509, "Duration": "58.48 min", "Samples": 512, "Total samples": 86237184, "BDF size": "0.241 GB", "RAM float32": "0.321 GB"},
    {"Participant": "s21", "Channels": 48, "Record": 1.0, "Records": 3551, "Duration": "59.18 min", "Samples": 512, "Total samples": 87269376, "BDF size": "0.244 GB", "RAM float32": "0.325 GB"},
    {"Participant": "s22", "Channels": 48, "Record": 1.0, "Records": 3719, "Duration": "61.98 min", "Samples": 512, "Total samples": 91398144, "BDF size": "0.255 GB", "RAM float32": "0.340 GB"},
    {"Participant": "s23", "Channels": 48, "Record": 1.0, "Records": 3601, "Duration": "60.02 min", "Samples": 512, "Total samples": 88498176, "BDF size": "0.247 GB", "RAM float32": "0.330 GB"},
    {"Participant": "s24", "Channels": 48, "Record": 1.0, "Records": 4712, "Duration": "78.53 min", "Samples": 512, "Total samples": 115802112, "BDF size": "0.324 GB", "RAM float32": "0.431 GB"},
    {"Participant": "s25", "Channels": 48, "Record": 1.0, "Records": 4120, "Duration": "68.67 min", "Samples": 512, "Total samples": 101253120, "BDF size": "0.283 GB", "RAM float32": "0.377 GB"},
    {"Participant": "s26", "Channels": 48, "Record": 1.0, "Records": 3913, "Duration": "65.22 min", "Samples": 512, "Total samples": 96165888, "BDF size": "0.269 GB", "RAM float32": "0.358 GB"},
    {"Participant": "s27", "Channels": 48, "Record": 1.0, "Records": 3798, "Duration": "63.30 min", "Samples": 512, "Total samples": 93339648, "BDF size": "0.261 GB", "RAM float32": "0.348 GB"},
    {"Participant": "s28", "Channels": 48, "Record": 1.0, "Records": 3527, "Duration": "58.78 min", "Samples": 512, "Total samples": 86679552, "BDF size": "0.242 GB", "RAM float32": "0.323 GB"},
    {"Participant": "s29", "Channels": 49, "Record": 1.0, "Records": 3978, "Duration": "66.30 min", "Samples": 512, "Total samples": 99800064, "BDF size": "0.279 GB", "RAM float32": "0.372 GB"},
    {"Participant": "s30", "Channels": 49, "Record": 1.0, "Records": 3665, "Duration": "61.08 min", "Samples": 512, "Total samples": 91947520, "BDF size": "0.257 GB", "RAM float32": "0.343 GB"},
    {"Participant": "s31", "Channels": 49, "Record": 1.0, "Records": 3696, "Duration": "61.60 min", "Samples": 512, "Total samples": 92725248, "BDF size": "0.259 GB", "RAM float32": "0.345 GB"},
    {"Participant": "s32", "Channels": 49, "Record": 1.0, "Records": 3524, "Duration": "58.73 min", "Samples": 512, "Total samples": 88410112, "BDF size": "0.247 GB", "RAM float32": "0.329 GB"},
]

final_summary_display_df: pd.DataFrame = pd.DataFrame(data)

print(final_summary_display_df.to_string(index=False))
# Out:
# Participant  Channels  Record  Records  Duration  Samples  Total samples BDF size RAM float32
#         s01        48     1.0     3869 64.48 min      512       95084544 0.266 GB    0.354 GB
#         s02        48     1.0     3703 61.72 min      512       91004928 0.254 GB    0.339 GB
#         s03        48     1.0     3885 64.75 min      512       95477760 0.267 GB    0.356 GB
#         s04        48     1.0     3301 55.02 min      512       81125376 0.227 GB    0.302 GB
#         s05        48     1.0     3916 65.27 min      512       96239616 0.269 GB    0.359 GB
#         s06        48     1.0     3586 59.77 min      512       88129536 0.246 GB    0.328 GB
#         s07        48     1.0     3571 59.52 min      512       87760896 0.245 GB    0.327 GB
#         s08        48     1.0     3517 58.62 min      512       86433792 0.242 GB    0.322 GB
#         s09        48     1.0     3767 62.78 min      512       92577792 0.259 GB    0.345 GB
# ...

# %%
final_summary_display_df["Total registers"] = (
    final_summary_display_df["Records"] * final_summary_display_df["Samples"]
)

final_summary_display_df = final_summary_display_df[
    [
        "Participant",
        "Channels",
        "Record",
        "Records",
        "Duration",
        "Samples",
        "Total registers",
        "BDF size",
        "RAM float32",
    ]
]

# %%
print(final_summary_display_df.to_string(index=False))
# Out:
# Participant  Channels  Record  Records  Duration  Samples  Total registers BDF size RAM float32
#         s01        48     1.0     3869 64.48 min      512          1980928 0.266 GB    0.354 GB
#         s02        48     1.0     3703 61.72 min      512          1895936 0.254 GB    0.339 GB
#         s03        48     1.0     3885 64.75 min      512          1989120 0.267 GB    0.356 GB
#         s04        48     1.0     3301 55.02 min      512          1690112 0.227 GB    0.302 GB
#         s05        48     1.0     3916 65.27 min      512          2004992 0.269 GB    0.359 GB
#         s06        48     1.0     3586 59.77 min      512          1836032 0.246 GB    0.328 GB
#         s07        48     1.0     3571 59.52 min      512          1828352 0.245 GB    0.327 GB
#         s08        48     1.0     3517 58.62 min      512          1800704 0.242 GB    0.322 GB
#         s09        48     1.0     3767 62.78 min      512          1928704 0.259 GB    0.345 GB
# ...

# %%
# =========================================================
# CALCULAR TOTALES
# =========================================================

total_registers: int = (
    final_summary_display_df["Total registers"].sum()
)

total_bdf_size_gb: float = (
    final_summary_display_df["BDF size"]
    .str.replace(" GB", "", regex=False)
    .astype(float)
    .sum()
)

total_ram_float32_gb: float = (
    final_summary_display_df["RAM float32"]
    .str.replace(" GB", "", regex=False)
    .astype(float)
    .sum()
)


# =========================================================
# FILA TOTAL
# =========================================================

total_row: pd.DataFrame = pd.DataFrame(
    [
        {
            "Participant": "TOTAL",
            "Channels": "",
            "Record": "",
            "Records": "",
            "Duration": "",
            "Samples": "",
            "Total registers": f"{total_registers:,}",
            "BDF size": f"{total_bdf_size_gb:.3f} GB",
            "RAM float32": f"{total_ram_float32_gb:.3f} GB",
        }
    ]
)


# =========================================================
# CONCATENAR FILA TOTAL
# =========================================================

final_summary_display_df = pd.concat(
    [
        final_summary_display_df,
        total_row,
    ],
    ignore_index=True,
)

print(final_summary_display_df.to_string(index=False))
# Out:
# Participant Channels Record Records  Duration Samples Total registers BDF size RAM float32
#         s01       48    1.0    3869 64.48 min     512         1980928 0.266 GB    0.354 GB
#         s02       48    1.0    3703 61.72 min     512         1895936 0.254 GB    0.339 GB
#         s03       48    1.0    3885 64.75 min     512         1989120 0.267 GB    0.356 GB
#         s04       48    1.0    3301 55.02 min     512         1690112 0.227 GB    0.302 GB
#         s05       48    1.0    3916 65.27 min     512         2004992 0.269 GB    0.359 GB
#         s06       48    1.0    3586 59.77 min     512         1836032 0.246 GB    0.328 GB
#         s07       48    1.0    3571 59.52 min     512         1828352 0.245 GB    0.327 GB
#         s08       48    1.0    3517 58.62 min     512         1800704 0.242 GB    0.322 GB
#         s09       48    1.0    3767 62.78 min     512         1928704 0.259 GB    0.345 GB
# ...
